# %%
from ultralytics import YOLO
from PIL import Image
import os

model_path = "best.pt"

test_images_dir = "./test_images"

model = YOLO(model_path)

image_files = [f for f in os.listdir(test_images_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

for image_file in image_files:
    image_path = os.path.join(test_images_dir, image_file)
    image = Image.open(image_path)
    results = model.predict(source=image, save=True) 

    print(f"Predictions for {image_file}: {results}")
# Out:
# 0: 640x480 1 mute, 5.3ms
# Speed: 2.3ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# Predictions for photo_2024-04-07_19-56-28.jpg: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'call', 1: 'no_gesture', 2: 'dislike', 3: 'fist', 4: 'four', 5: 'like', 6: 'mute', 7: 'ok', 8: 'one', 9: 'palm', 10: 'peace', 11: 'peace_inverted', 12: 'rock', 13: 'stop', 14: 'stop_inverted', 15: 'three', 16: 'three2', 17: 'two_up', 18: 'two_up_inverted'}
# obb: None
# orig_img: array([[[185, 197, 209],
#         [185, 197, 209],
#         [185, 197, 209],
#         ...,
#         [255, 255, 254],
#         [255, 255, 254],
#         [255, 255, 254]],
#
#        [[185, 197, 209],
#         [185, 197, 209],
#         [185, 197, 209],
#         ...,
#         [255, 255, 254],
#         [255, 255, 254],
#         [255, 255, 254]],
#
#        [[185, 197, 209],
#         [185, 197, 209],
#         [185, 197, 209],
#         ...,
#         [255, 255, 254],
#         [255, 255, 254],
#         [255, 255, 254]],
#
#        ...,
#
#        [[ 37,  32,  29],
#         [ 37,  32,  29],
#         [ 36,  31,  28],
#         ...,
#         [119, 134, 173],
#         [118, 133, 172],
#         [117, 131, 173]],
#
#        [[ 33,  28,  25],
#         [ 33,  28,  25],
#         [ 33,  28,  25],
#         ...,
#         [113, 128, 167],
#         [113, 127, 169],
#         [112, 126, 168]],
#
#        [[ 26,  21,  18],
#         [ 27,  22,  19],
#         [ 29,  24,  21],
#         ...,
#         [108, 123, 162],
#         [109, 123, 165],
#         [109, 123, 165]]], dtype=uint8)
# orig_shape: (1280, 960)
# path: './test_images/photo_2024-04-07_19-56-28.jpg'
# probs: None
# save_dir: 'runs/detect/predict3'
# speed: {'preprocess': 2.272367477416992, 'inference': 5.254030227661133, 'postprocess': 0.9987354278564453}]
#
# 0: 640x480 1 like, 5.6ms
# Speed: 2.3ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# Predictions for photo_2024-04-07_19-56-36.jpg: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'call', 1: 'no_gesture', 2: 'dislike', 3: 'fist', 4: 'four', 5: 'like', 6: 'mute', 7: 'ok', 8: 'one', 9: 'palm', 10: 'peace', 11: 'peace_inverted', 12: 'rock', 13: 'stop', 14: 'stop_inverted', 15: 'three', 16: 'three2', 17: 'two_up', 18: 'two_up_inverted'}
# obb: None
# orig_img: array([[[231, 237, 244],
#         [231, 237, 244],
#         [231, 237, 244],
#         ...,
#         [178, 171, 168],
#         [176, 169, 166],
#         [175, 168, 165]],
#
#        [[231, 237, 244],
#         [231, 237, 244],
#         [231, 237, 244],
#         ...,
#         [179, 172, 169],
#         [177, 170, 167],
#         [174, 167, 164]],
#
#        [[231, 237, 244],
#         [231, 237, 244],
#         [231, 237, 244],
#         ...,
#         [179, 172, 169],
#         [176, 169, 166],
#         [174, 167, 164]],
#
#        ...,
#
#        [[ 63,  87, 115],
#         [ 60,  84, 112],
#         [ 59,  81, 109],
#         ...,
#         [ 16,  35,  40],
#         [ 14,  33,  38],
#         [ 12,  31,  36]],
#
#        [[ 63,  87, 115],
#         [ 61,  85, 113],
#         [ 60,  82, 110],
#         ...,
#         [ 13,  32,  37],
#         [ 11,  30,  35],
#         [ 10,  29,  34]],
#
#        [[ 65,  89, 117],
#         [ 64,  86, 114],
#         [ 61,  83, 111],
#         ...,
#         [ 17,  36,  41],
#         [ 18,  37,  42],
#         [ 19,  38,  43]]], dtype=uint8)
# orig_shape: (1280, 960)
# path: './test_images/photo_2024-04-07_19-56-36.jpg'
# probs: None
# save_dir: 'runs/detect/predict3'
# speed: {'preprocess': 2.298116683959961, 'inference': 5.644083023071289, 'postprocess': 1.0559558868408203}]
#
# 0: 640x480 1 like, 5.2ms
# Speed: 2.2ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# Predictions for photo_2024-04-07_19-56-31.jpg: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'call', 1: 'no_gesture', 2: 'dislike', 3: 'fist', 4: 'four', 5: 'like', 6: 'mute', 7: 'ok', 8: 'one', 9: 'palm', 10: 'peace', 11: 'peace_inverted', 12: 'rock', 13: 'stop', 14: 'stop_inverted', 15: 'three', 16: 'three2', 17: 'two_up', 18: 'two_up_inverted'}
# obb: None
# orig_img: array([[[145, 165, 176],
#         [145, 165, 176],
#         [145, 165, 176],
#         ...,
#         [235, 244, 254],
#         [234, 243, 253],
#         [233, 241, 254]],
#
#        [[145, 165, 176],
#         [145, 165, 176],
#         [145, 165, 176],
#         ...,
#         [234, 243, 253],
#         [233, 242, 252],
#         [232, 240, 253]],
#
#        [[145, 165, 176],
#         [145, 165, 176],
#         [145, 165, 176],
#         ...,
#         [233, 242, 252],
#         [231, 240, 250],
#         [230, 238, 251]],
#
#        ...,
#
#        [[ 37,  30,  27],
#         [ 40,  33,  30],
#         [ 43,  36,  33],
#         ...,
#         [ 22,  24,  25],
#         [ 21,  23,  24],
#         [ 20,  22,  23]],
#
#        [[ 40,  33,  30],
#         [ 40,  33,  30],
#         [ 40,  33,  30],
#         ...,
#         [ 20,  22,  23],
#         [ 22,  24,  25],
#         [ 24,  26,  27]],
#
#        [[ 40,  33,  30],
#         [ 38,  31,  28],
#         [ 36,  29,  26],
#         ...,
#         [ 20,  22,  23],
#         [ 25,  27,  28],
#         [ 29,  31,  32]]], dtype=uint8)
# orig_shape: (1280, 960)
# path: './test_images/photo_2024-04-07_19-56-31.jpg'
# probs: None
# save_dir: 'runs/detect/predict3'
# speed: {'preprocess': 2.2363662719726562, 'inference': 5.235910415649414, 'postprocess': 1.0426044464111328}]
#
# 0: 640x480 1 peace, 5.4ms
# Speed: 2.3ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# Predictions for photo_2024-04-07_19-56-33.jpg: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'call', 1: 'no_gesture', 2: 'dislike', 3: 'fist', 4: 'four', 5: 'like', 6: 'mute', 7: 'ok', 8: 'one', 9: 'palm', 10: 'peace', 11: 'peace_inverted', 12: 'rock', 13: 'stop', 14: 'stop_inverted', 15: 'three', 16: 'three2', 17: 'two_up', 18: 'two_up_inverted'}
# obb: None
# orig_img: array([[[227, 233, 240],
#         [227, 233, 240],
#         [227, 233, 240],
#         ...,
#         [242, 237, 239],
#         [242, 237, 239],
#         [242, 237, 239]],
#
#        [[227, 233, 240],
#         [227, 233, 240],
#         [227, 233, 240],
#         ...,
#         [241, 236, 238],
#         [241, 236, 238],
#         [241, 236, 238]],
#
#        [[227, 233, 240],
#         [227, 233, 240],
#         [227, 233, 240],
#         ...,
#         [239, 234, 236],
#         [239, 234, 236],
#         [239, 234, 236]],
#
#        ...,
#
#        [[ 89,  97, 114],
#         [ 83,  92, 106],
#         [ 75,  84,  97],
#         ...,
#         [ 14,  20,  25],
#         [ 13,  19,  24],
#         [ 13,  19,  24]],
#
#        [[ 93, 103, 121],
#         [ 84,  94, 112],
#         [ 81,  91, 108],
#         ...,
#         [ 12,  18,  23],
#         [ 12,  18,  23],
#         [ 12,  18,  23]],
#
#        [[ 94, 105, 125],
#         [ 82,  94, 112],
#         [ 82,  92, 109],
#         ...,
#         [ 10,  16,  21],
#         [ 10,  16,  21],
#         [ 11,  17,  22]]], dtype=uint8)
# orig_shape: (1280, 960)
# path: './test_images/photo_2024-04-07_19-56-33.jpg'
# probs: None
# save_dir: 'runs/detect/predict3'
# speed: {'preprocess': 2.3429393768310547, 'inference': 5.396127700805664, 'postprocess': 1.0538101196289062}]
# Prediction complete.
